# %%
import pandas as pd
import numpy as np

# %%
file_path='/content/drive/MyDrive/project/price_data_short.csv'
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    baseFare  reservationCharge  superfastCharge  fuelAmount  totalConcession  \
# 0      1059                 60                0         0.0                0
# 1       626                 50                0         0.0                0
# 2       441                 40                0         0.0                0
# 3       125                 20                0         0.0                0
# 4      1059                 60                0         0.0                0
#
#    tatkalFare  serviceTax  otherCharge  cateringCharge  dynamicFare  \
# 0           0        56.0            0               0            0
# 1           0        34.0            0               0            0
# 2           0        24.0            0               0            0
# 3           0         0.0            0               0            0
# 4           0        56.0            0               0            0
#
#    totalFare                                       availability  trainNumber  \
# 0       1175  [{'date': '2-12-2023', 'status': 'AVAILABLE-00...        11464
# 1        710  [{'date': '2-12-2023', 'status': 'AVAILABLE-00...        11464
# 2        505  [{'date': '2-12-2023', 'status': 'AVAILABLE-01...        11464
# 3        145  [{'date': '2-12-2023', 'status': 'AVAILABLE-00...        11464
# 4       1175  [{'date': '2-12-2023', 'status': 'AVAILABLE-00...        11464
#
#                     timeStamp fromStnCode toStnCode classCode  distance  \
# 0  2023-10-03 22:13:07.781307         JBP      SRID        1A        54
# 1  2023-10-03 22:13:07.781307         JBP      SRID        2A        54
# 2  2023-10-03 22:13:07.781307         JBP      SRID        3A        54
# 3  2023-10-03 22:13:07.781307         JBP      SRID        SL        54
# 4  2023-10-03 22:13:07.781307         JBP       KKB        1A        69
#
#    duration
# 0      33.0
# 1      33.0
# 2      33.0
# 3      33.0
# 4      49.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 326643 entries, 0 to 326642
# Data columns (total 19 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   baseFare           326643 non-null  int64
#  1   reservationCharge  326643 non-null  int64
#  2   superfastCharge    326643 non-null  int64
#  3   fuelAmount         326643 non-null  float64
#  4   totalConcession    326643 non-null  int64
#  5   tatkalFare         326643 non-null  int64
#  6   serviceTax         326643 non-null  float64
#  7   otherCharge        326643 non-null  int64
#  8   cateringCharge     326643 non-null  int64
#  9   dynamicFare        326643 non-null  int64
#  10  totalFare          326643 non-null  int64
#  11  availability       326643 non-null  object
#  12  trainNumber        326643 non-null  int64
#  13  timeStamp          326643 non-null  object
#  14  fromStnCode        326643 non-null  object
#  15  toStnCode          326643 non-null  object
#  16  classCode          326643 non-null  object
#  17  distance           326643 non-null  int64
#  18  duration           326643 non-null  float64
# dtypes: float64(3), int64(11), object(5)
# memory usage: 47.3+ MB

# %%
df.shape
# Out:
# (326643, 19)

# %%
df.isnull().sum()
# Out:
# baseFare             0
# reservationCharge    0
# superfastCharge      0
# fuelAmount           0
# totalConcession      0
# tatkalFare           0
# serviceTax           0
# otherCharge          0
# cateringCharge       0
# dynamicFare          0
# totalFare            0
# availability         0
# trainNumber          0
# timeStamp            0
# fromStnCode          0
# toStnCode            0
# classCode            0
# distance             0
# duration             0
# dtype: int64

# %%
df.describe()
# Out:
#             baseFare  reservationCharge  superfastCharge  fuelAmount  \
# count  326643.000000      326643.000000    326643.000000    326643.0
# mean      890.075122          38.157805        20.058091         0.0
# std       793.765711          14.324952        24.646072         0.0
# min        30.000000          15.000000         0.000000         0.0
# 25%       362.000000          20.000000         0.000000         0.0
# 50%       626.000000          40.000000         0.000000         0.0
# 75%      1222.000000          50.000000        45.000000         0.0
# max      6541.000000          60.000000        75.000000         0.0
#
#        totalConcession  tatkalFare     serviceTax    otherCharge  \
# count         326643.0    326643.0  326643.000000  326643.000000
# mean               0.0         0.0      42.761510       0.053208
# std                0.0         0.0      45.080793       1.018403
# min                0.0         0.0       0.000000       0.000000
# 25%                0.0         0.0       0.000000       0.000000
# 50%                0.0         0.0      34.000000       0.000000
# 75%                0.0         0.0      65.000000       0.000000
# max                0.0         0.0     334.000000      25.000000
#
#        cateringCharge    dynamicFare      totalFare    trainNumber  \
# count   326643.000000  326643.000000  326643.000000  326643.000000
# mean         4.990601       4.224771    1000.355281   14597.751870
# std         42.586032      49.050982     872.003147    4734.686291
# min          0.000000       0.000000      45.000000    1027.000000
# 25%          0.000000       0.000000     395.000000   12316.000000
# 50%          0.000000       0.000000     710.000000   13020.000000
# 75%          0.000000       0.000000    1370.000000   18477.000000
# max       1365.000000    1518.000000    8375.000000   22645.000000
#
#             distance       duration
# count  326643.000000  326643.000000
# mean      587.745153     644.124564
# std       548.858324     581.665800
# min         1.000000   -1423.000000
# 25%       164.000000     193.000000
# 50%       404.000000     462.000000
# 75%       861.000000     936.000000
# max      3149.000000    3225.000000

# %%
for columns in df:
    print(columns,":", df[columns].nunique())
# Out:
# baseFare : 1840
# reservationCharge : 5
# superfastCharge : 5
# fuelAmount : 1
# totalConcession : 1
# tatkalFare : 1
# serviceTax : 276
# otherCharge : 3
# cateringCharge : 69
# dynamicFare : 475
# totalFare : 976
# availability : 27639
# trainNumber : 533
# timeStamp : 579
# fromStnCode : 1480
# toStnCode : 1594
# classCode : 6
# distance : 2759
# duration : 2912

# %%
# their three columns which has 1 value so they are not get any impact on the data
# also their is negligible impact of othercharge on the fare
df2=df.drop(['fuelAmount','totalConcession','tatkalFare','otherCharge'],axis=1)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 326643 entries, 0 to 326642
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   baseFare           326643 non-null  int64
#  1   reservationCharge  326643 non-null  int64
#  2   superfastCharge    326643 non-null  int64
#  3   serviceTax         326643 non-null  float64
#  4   cateringCharge     326643 non-null  int64
#  5   dynamicFare        326643 non-null  int64
#  6   totalFare          326643 non-null  int64
#  7   availability       326643 non-null  object
#  8   trainNumber        326643 non-null  int64
#  9   timeStamp          326643 non-null  object
#  10  fromStnCode        326643 non-null  object
#  11  toStnCode          326643 non-null  object
#  12  classCode          326643 non-null  object
#  13  distance           326643 non-null  int64
#  14  duration           326643 non-null  float64
# dtypes: float64(2), int64(8), object(5)
# memory usage: 37.4+ MB

# %%
df2.shape
# Out:
# (326643, 15)

# %%
df2.dtypes
# Out:
# baseFare               int64
# reservationCharge      int64
# superfastCharge        int64
# serviceTax           float64
# cateringCharge         int64
# dynamicFare            int64
# totalFare              int64
# availability          object
# trainNumber            int64
# timeStamp             object
# fromStnCode           object
# toStnCode             object
# classCode             object
# distance               int64
# duration             float64
# dtype: object

# %%
print(df2['reservationCharge'].unique())
print(df2['superfastCharge'].unique())
print(df2['classCode'].unique())
# Out:
# [60 50 40 20 15]
# [ 0 45 30 15 75]
# ['1A' '2A' '3A' 'SL' '2S' 'CC']

# %%
df2.drop_duplicates(inplace=True)

# %%
df2.shape
# Out:
# (326643, 15)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count plots for categorical columns
plt.figure(figsize=(10, 6))
sns.countplot(data=df2, x='classCode')
plt.title('Count Plot of Class Code')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # People Mostly prefer SL, 3A and 2A tickets during travelling

# %% [markdown]
# # one hot encoding
# - price is depends on the classcode so we make sepearte columns of the classcode categorical column

# %%
df_ohe = pd.get_dummies(df['classCode'])

# %%
df_ohe.shape
# Out:
# (326643, 6)

# %%
df_ohe.head()
# Out:
#       1A     2A     2S     3A     CC     SL
# 0   True  False  False  False  False  False
# 1  False   True  False  False  False  False
# 2  False  False  False   True  False  False
# 3  False  False  False  False  False   True
# 4   True  False  False  False  False  False

# %%
df_now = df2[['classCode', 'distance', 'duration']]
y = df2['baseFare']

# %%
merged = pd.concat([df_now,df_ohe ], axis=1)
x = merged.drop(['classCode'], axis=1)

# %%
x.head()
# Out:
#    distance  duration     1A     2A     2S     3A     CC     SL
# 0        54      33.0   True  False  False  False  False  False
# 1        54      33.0  False   True  False  False  False  False
# 2        54      33.0  False  False  False   True  False  False
# 3        54      33.0  False  False  False  False  False   True
# 4        69      49.0   True  False  False  False  False  False

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,
                                                 random_state=7)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((228650, 8), (97993, 8), (228650,), (97993,))

# %% [markdown]
#  # predict the base on the distance classcode and time

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score

# Linear Regression
lr_model = LinearRegression()
lr_model.fit(x_train, y_train)
lr_preds = lr_model.predict(x_test)
print("Linear Regression:")
print("MSE:", mean_squared_error(y_test, lr_preds))
print("R-squared:", r2_score(y_test, lr_preds))

# Decision Tree Regression
dt_model = DecisionTreeRegressor()
dt_model.fit(x_train, y_train)
dt_preds = dt_model.predict(x_test)
print("\nDecision Tree Regression:")
print("MSE:", mean_squared_error(y_test, dt_preds))
print("R-squared:", r2_score(y_test, dt_preds))

# Random Forest Regression
rf_model = RandomForestRegressor()
rf_model.fit(x_train, y_train)
rf_preds = rf_model.predict(x_test)
print("\nRandom Forest Regression:")
print("MSE:", mean_squared_error(y_test, rf_preds))
print("R-squared:", r2_score(y_test, rf_preds))

# K-Nearest Neighbors Regression
knn_model = KNeighborsRegressor()
knn_model.fit(x_train, y_train)
knn_preds = knn_model.predict(x_test)
print("\nK-Nearest Neighbors Regression:")
print("MSE:", mean_squared_error(y_test, knn_preds))
print("R-squared:", r2_score(y_test, knn_preds))
# Out:
# Linear Regression:
# MSE: 93335.89235465175
# R-squared: 0.8509776751748395
#
# Decision Tree Regression:
# MSE: 26292.71186012296
# R-squared: 0.9580204254922055
#
# Random Forest Regression:
# MSE: 16107.081999359398
# R-squared: 0.9742830464771959
#
# K-Nearest Neighbors Regression:
# MSE: 332947.73286949063
# R-squared: 0.4684076624140706

# %%
from sklearn.linear_model import Ridge, Lasso

# Ridge Regression
ridge_model = Ridge()
ridge_model.fit(x_train, y_train)
ridge_preds = ridge_model.predict(x_test)
print("\nRidge Regression:")
print("MSE:", mean_squared_error(y_test, ridge_preds))
print("R-squared:", r2_score(y_test, ridge_preds))

# Lasso Regression
lasso_model = Lasso()
lasso_model.fit(x_train, y_train)
lasso_preds = lasso_model.predict(x_test)
print("\nLasso Regression:")
print("MSE:", mean_squared_error(y_test, lasso_preds))
print("R-squared:", r2_score(y_test, lasso_preds))
# Out:
# Ridge Regression:
# MSE: 93335.81852658538
# R-squared: 0.8509777930505014
#
# Lasso Regression:
# MSE: 93417.45980222187
# R-squared: 0.8508474426312778

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Gradient Boosting Regression
gb_model = GradientBoostingRegressor()
gb_model.fit(x_train, y_train)
gb_preds = gb_model.predict(x_test)
print("\nGradient Boosting Regression:")
print("MSE:", mean_squared_error(y_test, gb_preds))
print("R-squared:", r2_score(y_test, gb_preds))
# Out:
# Gradient Boosting Regression:
# MSE: 15275.475133925693
# R-squared: 0.9756108099484723

# %%
import pandas as pd

# Assuming 'gb_model' is your best performing model (Gradient Boosting in this case)

new_data = pd.DataFrame({
    'distance': [54],
    'duration': [33],
    '1A': [1],
    '2A': [0],
    '2S': [0],
    '3A': [0],

    'CC': [0],

    'SL': [0]
})

predicted_basefare = lr_model.predict(new_data)
print("Predicted Base Fare:", predicted_basefare[0])
# Out:
# Predicted Base Fare: 1531.6890942628024

# %%
import pandas as pd

#linear regression
new_data = pd.DataFrame({
    'distance': [54],
    'duration': [33],
    '1A': [1],
    '2A': [0],
    '2S': [0],
    '3A': [0],

    'CC': [0],

    'SL': [0]
})

predicted_basefare = lr_model.predict(new_data)
print("Predicted Base Fare:", predicted_basefare[0])
# Out:
# Predicted Base Fare: 1531.6890942628024

# %%
import pandas as pd

# knn k-nearest neibhour
new_data = pd.DataFrame({
    'distance': [54],
    'duration': [33],
    '1A': [1],
    '2A': [0],
    '2S': [0],
    '3A': [0],

    'CC': [0],

    'SL': [0]
})

predicted_basefare = knn_model.predict(new_data)
print("Predicted Base Fare:", predicted_basefare[0])
# Out:
# Predicted Base Fare: 625.6

# %%
import pandas as pd

# decision tree
new_data = pd.DataFrame({
    'distance': [54],
    'duration': [33],
    '1A': [1],
    '2A': [0],
    '2S': [0],
    '3A': [0],

    'CC': [0],

    'SL': [0]
})

predicted_basefare = dt_model.predict(new_data)
print("Predicted Base Fare:", predicted_basefare[0])
# Out:
# Predicted Base Fare: 1059.0

# %%
import pandas as pd

# random forest
new_data = pd.DataFrame({
    'distance': [54],
    'duration': [33],
    '1A': [1],
    '2A': [0],
    '2S': [0],
    '3A': [0],

    'CC': [0],

    'SL': [0]
})

predicted_basefare = rf_model.predict(new_data)
print("Predicted Base Fare:", predicted_basefare[0])
# Out:
# Predicted Base Fare: 1061.254

# %%
xy_merge=df[['baseFare','reservationCharge','superfastCharge', 'serviceTax', 'cateringCharge', 'distance', 'duration']]
yz=df2['totalFare']

# %%
xy = pd.concat([xy_merge,df_ohe ], axis=1)

# %%
xy.head()
# Out:
#    baseFare  reservationCharge  superfastCharge  serviceTax  cateringCharge  \
# 0      1059                 60                0        56.0               0
# 1       626                 50                0        34.0               0
# 2       441                 40                0        24.0               0
# 3       125                 20                0         0.0               0
# 4      1059                 60                0        56.0               0
#
#    distance  duration     1A     2A     2S     3A     CC     SL
# 0        54      33.0   True  False  False  False  False  False
# 1        54      33.0  False   True  False  False  False  False
# 2        54      33.0  False  False  False   True  False  False
# 3        54      33.0  False  False  False  False  False   True
# 4        69      49.0   True  False  False  False  False  False

# %%
from sklearn.model_selection import train_test_split
xy_train,xy_test,yz_train,yz_test = train_test_split(xy,yz,test_size=0.3,
                                                 random_state=7)

# %%
xy_train.shape,xy_test.shape,yz_train.shape,yz_test.shape
# Out:
# ((228650, 13), (97993, 13), (228650,), (97993,))

# %%
# Linear Regression
lr_model = LinearRegression()
lr_model.fit(xy_train, yz_train)
lr_preds = lr_model.predict(xy_test)
print("Linear Regression:")
print("MSE:", mean_squared_error(yz_test, lr_preds))
print("R-squared:", r2_score(yz_test, lr_preds))

# Decision Tree Regression
dt_model = DecisionTreeRegressor()
dt_model.fit(xy_train, yz_train)
dt_preds = dt_model.predict(xy_test)
print("\nDecision Tree Regression:")
print("MSE:", mean_squared_error(yz_test, dt_preds))
print("R-squared:", r2_score(yz_test, dt_preds))

# Random Forest Regression
rf_model = RandomForestRegressor()
rf_model.fit(xy_train, yz_train)
rf_preds = rf_model.predict(xy_test)
print("\nRandom Forest Regression:")
print("MSE:", mean_squared_error(yz_test, rf_preds))
print("R-squared:", r2_score(yz_test, rf_preds))

# K-Nearest Neighbors Regression
knn_model = KNeighborsRegressor()
knn_model.fit(xy_train, yz_train)
knn_preds = knn_model.predict(xy_test)
print("\nK-Nearest Neighbors Regression:")
print("MSE:", mean_squared_error(yz_test, knn_preds))
print("R-squared:", r2_score(yz_test, knn_preds))


# Ridge Regression
ridge_model = Ridge()
ridge_model.fit(xy_train, yz_train)
ridge_preds = ridge_model.predict(xy_test)
print("\nRidge Regression:")
print("MSE:", mean_squared_error(yz_test, ridge_preds))
print("R-squared:", r2_score(yz_test, ridge_preds))

# Lasso Regression
lasso_model = Lasso()
lasso_model.fit(xy_train, yz_train)
lasso_preds = lasso_model.predict(xy_test)
print("\nLasso Regression:")
print("MSE:", mean_squared_error(yz_test, lasso_preds))
print("R-squared:", r2_score(yz_test, lasso_preds))



# Gradient Boosting Regression
gb_model = GradientBoostingRegressor()
gb_model.fit(xy_train, yz_train)
gb_preds = gb_model.predict(xy_test)
print("\nGradient Boosting Regression:")
print("MSE:", mean_squared_error(yz_test, gb_preds))
print("R-squared:", r2_score(yz_test, gb_preds))
# Out:
# Linear Regression:
# MSE: 1310.1370183412384
# R-squared: 0.9982660682044003
#
# Decision Tree Regression:
# MSE: 83.64284616237957
# R-squared: 0.9998893008987572
#
# Random Forest Regression:
# MSE: 23.716047272667858
# R-squared: 0.9999686124368243
#
# K-Nearest Neighbors Regression:
# MSE: 404.3535252518037
# R-squared: 0.9994648487720891
#
# Ridge Regression:
# MSE: 1310.1354981005284
# R-squared: 0.9982660702163988
#
# Lasso Regression:
# MSE: 1377.2759521820046
# R-squared: 0.9981772115959087
#
# Gradient Boosting Regression:
# MSE: 163.4407766258112
# R-squared: 0.9997836904420517
